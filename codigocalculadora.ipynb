# %%
from tkinter import *
import tkinter as tk

def btn_clicked():
    print('')
def btn_1():
    print('xx')
def soma():
    return ''
def substracao():
    return ''
def divisao():
    return ''
def mult():
    return ''
def limpar():
    return ''
#
def label_x(text):
    nm_formatado = text
    label_n1['text'] = text

#####################################################################################################################################
window = Tk()
window.title('Calculadora')
window.geometry("426x470")
window.configure(bg = "#7b94ee")
canvas = Canvas(
    window,
    bg = "#7b94ee",
    height = 470,
    width = 426,
    bd = 0,
    highlightthickness = 0,
    relief = "ridge")
canvas.place(x = 0, y = 0)
########################################################################################################################################
label_n1 = tk.Label(text='0', font=('Arial', 36), bg='white')
label_n1.place(x=350, y=12)

#label_x = tk.Label(text='x')
#label_x.place(x=55, y=43)
#
#label_n2 = tk.Label(text='n2')
#label_n2.place(x=75, y=43)
#########################################################################################################################################
img0 = PhotoImage(file = f"img0.png")
b_1 = Button(
    text='1',
    image = img0,
    borderwidth = 0,
    highlightthickness = 0,
    command = lambda: label_x(b_1['text']),
    relief = "flat")
b_1.place(
    x = 20, y = 106,
    width = 79,
    height = 69)


##################################
img1 = PhotoImage(file = f"img1.png")
b_2 = Button(text='2',
    image = img1,
    borderwidth = 0,
    highlightthickness = 0,
    command = lambda: label_x(b_2['text']),
    relief = "flat")

b_2.place(
    x = 116, y = 106,
    width = 79,
    height = 69)

img2 = PhotoImage(file = f"img2.png")
b_3 = Button(
    text='3',
    image = img2,
    borderwidth = 0,
    highlightthickness = 0,
    command = lambda: label_x(b_3['text']),
    relief = "flat")

b_3.place(
    x = 213, y = 106,
    width = 79,
    height = 69)

img3 = PhotoImage(file = f"img3.png")
b_4 = Button(
    text='4',
    image = img3,
    borderwidth = 0,
    highlightthickness = 0,
    command = lambda: label_x(b_4['text']),
    relief = "flat")

b_4.place(
    x = 20, y = 194,
    width = 79,
    height = 69)

img4 = PhotoImage(file = f"img4.png")
b_5 = Button(
    text='5',
    image = img4,
    borderwidth = 0,
    highlightthickness = 0,
    command = lambda: label_x(b_5['text']),
    relief = "flat")

b_5.place(
    x = 114, y = 194,
    width = 79,
    height = 69)

img5 = PhotoImage(file = f"img5.png")
b_6 = Button(
    text='6',
    image = img5,
    borderwidth = 0,
    highlightthickness = 0,
    command = lambda: label_x(b_6['text']),
    relief = "flat")

b_6.place(
    x = 213, y = 194,
    width = 79,
    height = 69)

img6 = PhotoImage(file = f"img6.png")
b_7 = Button(
    text='7',
    image = img6,
    borderwidth = 0,
    highlightthickness = 0,
    command = lambda: label_x(b_7['text']),
    relief = "flat")

b_7.place(
    
    x = 20, y = 282,
    width = 79,
    height = 69)

img7 = PhotoImage(file = f"img7.png")
b_8 = Button(
    text='8',
    image = img7,
    borderwidth = 0,
    highlightthickness = 0,
    command = lambda: label_x(b_8['text']),
    relief = "flat")

b_8.place(
    x = 116, y = 282,
    width = 79,
    height = 69)

img8 = PhotoImage(file = f"img8.png")
b_9 = Button(
    text='9',
    image = img8,
    borderwidth = 0,
    highlightthickness = 0,
    command = lambda: label_x(b_9['text']),
    relief = "flat")

b_9.place(
    x = 213, y = 281,
    width = 79,
    height = 69)

img9 = PhotoImage(file = f"img9.png")
b_0 = Button(
    text='0',
    image = img9,
    borderwidth = 0,
    highlightthickness = 0,
    command = lambda: label_x(b_0['text']),
    relief = "flat")

b_0.place(
    x = 116, y = 368,
    width = 79,
    height = 69)

#####################################################################################################

img10 = PhotoImage(file = f"img10.png")
b10 = Button(
    image = img10,
    borderwidth = 0,
    highlightthickness = 0,
    command = btn_clicked,
    relief = "flat")

b10.place(
    x = 20, y = 368,
    width = 79,
    height = 69)

img11 = PhotoImage(file = f"img11.png")
b11 = Button(
    image = img11,
    borderwidth = 0,
    highlightthickness = 0,
    command = btn_clicked,
    relief = "flat")

b11.place(
    x = 213, y = 368,
    width = 79,
    height = 69)

img12 = PhotoImage(file = f"img12.png")
b12 = Button(
    image = img12,
    borderwidth = 0,
    highlightthickness = 0,
    command = btn_clicked,
    relief = "flat")

b12.place(
    x = 334, y = 106,
    width = 79,
    height = 69)

img13 = PhotoImage(file = f"img13.png")
b13 = Button(
    image = img13,
    borderwidth = 0,
    highlightthickness = 0,
    command = btn_clicked,
    relief = "flat")

b13.place(
    x = 334, y = 191,
    width = 79,
    height = 69)

img14 = PhotoImage(file = f"img14.png")
b14 = Button(
    image = img14,
    borderwidth = 0,
    highlightthickness = 0,
    command = btn_clicked,
    relief = "flat")

b14.place(
    x = 334, y = 282,
    width = 79,
    height = 69)

img15 = PhotoImage(file = f"img15.png")
b15 = Button(
    image = img15,
    borderwidth = 0,
    highlightthickness = 0,
    command = btn_clicked,
    relief = "flat")

b15.place(
    x = 334, y = 368,
    width = 79,
    height = 69)

background_img = PhotoImage(file = f"background.png")
background = canvas.create_image(
    213.0, 41.0,
    image=background_img)

window.resizable(False, False)
window.mainloop()
